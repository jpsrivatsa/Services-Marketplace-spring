# %%
import json

# %%
import requests

# %%
BASE_URL = "http://localhost:8080/api/auth"

# %%
url = f"{BASE_URL}/register"

# %%
headers = {
        "Content-Type": "application/json"
}
data = {
  "username": "testuserwithmail",
  "email": "coderscolony7@gmail.com",
  "phoneNumber": "5050505050",
  "password": "password123",
  "firstName": "John",
  "lastName": "Doe",
  "address": "123 Street",
  "city": "CityName",
  "state": "StateName",
  "country": "CountryName",
  "role": {
    "name":"user"
  }
}

# %%
response = requests.post(url, json=data, headers=headers)

# %%
response.json()
# Out:
# {'error': 'Username already exists'}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
login_url = f"{BASE_URL}/login"

# %%
login_url
# Out:
# 'http://localhost:8080/api/auth/login'

# %%
login_data = {
    "username": "testuser",
    "password": "password123"
}

# %%
response = requests.post(login_url, json=login_data)

# %%
response.json()
# Out:
# {'role': 'user',
#  'token': 'eyJhbGciOiJIUzI1NiJ9.eyJyb2xlIjoidXNlciIsInVzZXJuYW1lIjoidGVzdHVzZXIiLCJzdWIiOiJ0ZXN0dXNlciIsImlhdCI6MTc0NjAyMDU1OSwiZXhwIjoxNzQ2MDU2NTU5fQ.elixUHUTVcNglovhuXvWtMO1MYCqBevE1RQCKpseo9Y'}

# %%
k = response.json()['token']

# %%
headers = {
        "Content-Type": "application/json",
        "Authorisation": "Bearer " + k
}

# %%
headers
# Out:
# {'Content-Type': 'application/json',
#  'Authorisation': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJyb2xlIjoidXNlciIsInVzZXJuYW1lIjoidGVzdHVzZXIiLCJzdWIiOiJ0ZXN0dXNlciIsImlhdCI6MTc0NjAxOTQ4MSwiZXhwIjoxNzQ2MDU1NDgxfQ.MkZBe0jJLJuWd52D2t0iSLQ3Ecy9j0gEKNmEIDwZyBg'}

# %%
token = response.json()['token']

# %%
forgotpassword_url = f"{BASE_URL}/forgotPassword"

# %%
forgotpassword_url
# Out:
# 'http://localhost:8080/api/auth/forgotPassword'

# %%
payload = {
    "username":"testuserwithmail"
}

# %%
resetpassword_url = f"{BASE_URL}/resetPassword"

# %%
rp = {
    "email": "coderscolony7@gmail.com",
    "token": "bd2e0165-1035-4eb6-9e89-65192950807f",
    "new_password": "password1234"
}

# %%
response = requests.post(forgotpassword_url, json=payload)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\jpsri\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#
# ...

# %%
response.json()
# Out:
# {'message': 'Password Reset Successfully'}

# %%
token = k

# %%
headers_user = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application/json'  # Optional, if you need to specify the content type
}

# %%
headers_user
# Out:
# {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJyb2xlIjoidXNlciIsInVzZXJuYW1lIjoidGVzdHVzZXIiLCJzdWIiOiJ0ZXN0dXNlciIsImlhdCI6MTc0NjAyMDU1OSwiZXhwIjoxNzQ2MDU2NTU5fQ.elixUHUTVcNglovhuXvWtMO1MYCqBevE1RQCKpseo9Y',
#  'Content-Type': 'application/json'}

# %%
headers_partner = {
    'Authorization': f'Bearer {token}',
    'Content-Type': 'application/json'  # Optional, if you need to specify the content type
}

# %%
category_url = f"{BASE_URL}/api/categories"

# %%
services_url = f"{BASE_URL}/api/services/myServices"

# %%
headers
# Out:
# {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJyb2xlIjoidXNlciIsInVzZXJuYW1lIjoidGVzdHVzZXIiLCJzdWIiOiJ0ZXN0dXNlciIsImlhdCI6MTc0NDQzNDY5MSwiZXhwIjoxNzQ0NDcwNjkxfQ.0Q7-ENQDaNqOaq0_N_47OVZM-iAvPugaLIXbNQ7d300',
#  'Content-Type': 'application/json'}

# %%
category_url = 'http://localhost:8080/api/categories'

# %%
service_url = "http://localhost:8080/api/services/"

# %%
payload = {
  "category": {
    "shortName": "Electrician"
  },
  "address":"Mysore 11th main"
  "description": "Fix grounding isssue in kitchen exhaust fan",
  "price": 500.0,
  "scheduledDate": "2025-04-15",
  "scheduledTime": "10:30:00",
  "expectedCompletion": "2025-04-15T12:30:00",
  "additionalComments": "Bring necessary tools"
}

# %%
services_url = 'http://localhost:8080/api/services/getService/{}'

# %%
services_url
# Out:
# 'http://localhost:8080/api/services/myServices'

# %%
response = requests.get(services_url,headers=headers_user)

# %%
response.json()
# Out:
# [{'serviceId': 6,
#   'serviceRequestId': 'SA0620624175268399',
#   'servicer': None,
#   'servicee': {'id': None,
#    'username': None,
#    'email': 'testuser@example.com',
#    'phoneNumber': '1234567890',
#    'password': None,
#    'firstName': 'John',
#    'lastName': None,
#    'address': None,
#    'city': None,
#    'state': None,
#    'country': None,
#    'role': None},
#   'category': 'Tutor/ Teacher',
#   'description': 'teach AI to kids',
#   'address': '4th main mysore',
#   'price': 45500.0,
#   'scheduledDate': '2025-03-28',
#   'scheduledTime': '04:00:00',
#   'expectedCompletion': '2025-03-29T10:30:00',
#   'status': 'Requested',
#   'cancellationReason': None,
#   'additionalComments': None,
#   'attachments': None,
#   'createdBy': 'testuser',
#   'updatedBy': None,
#   'createdAt': '2025-05-01T00:09:47.006613',
#   'updatedAt': None}]

# %%
assign_url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 assign_url
#
# NameError: name 'assign_url' is not defined

# %%
service_id = 'SA0620624175268399'

# %%
assign_url = f"http://localhost:8080/api/services/assignToMe/{service_id}"

# %%
fulfill_url = f"http://localhost:8080/api/services/markAsFulfilled/{service_id}"

# %%
cancel_url = f"http://localhost:8080/api/services/cancelService/{service_id}"

# %%
fulfill_url
# Out:
# 'http://localhost:8080/api/services/markAsFulfilled/SA6093499907056338'

# %%
complete_url = f"http://localhost:8080/api/services/markAsCompleted/{service_id}"

# %%
services_url = f"http://localhost:8080/api/services/myServices"

# %%
sindle_url = f"http://localhost:8080/api/services/getService/{service_id}"

# %%
update_url = f"http://localhost:8080/api/services/update/{service_id}"

# %%
response = requests.post(assign_url, headers=headers_user)

# %%
response.json()
# Out:
# {'message': 'Not allowed to assign service to you. Invalid account role'}

# %%
response = requests.post(assign_url, headers=headers)

# %%
response = requests.get(sindle_url, headers=headers_user)

# %%
response.json()
# Out:
# {'service': {'serviceId': 6,
#   'serviceRequestId': 'SA0620624175268399',
#   'servicer': None,
#   'servicee': {'id': None,
#    'username': None,
#    'email': 'testuser@example.com',
#    'phoneNumber': '1234567890',
#    'password': None,
#    'firstName': 'John',
#    'lastName': None,
#    'address': None,
#    'city': None,
#    'state': None,
#    'country': None,
#    'role': None},
#   'category': 'Tutor/ Teacher',
#   'description': 'teach AI to kids',
#   'address': '4th main mysore',
#   'price': 45500.0,
#   'scheduledDate': '2025-03-28',
#   'scheduledTime': '04:00:00',
#   'expectedCompletion': '2025-03-29T10:30:00',
#   'status': 'Requested',
#   'cancellationReason': None,
#   'additionalComments': None,
#   'attachments': None,
#   'createdBy': 'testuser',
#   'updatedBy': None,
#   'createdAt': '2025-05-01T00:09:47.006613',
#   'updatedAt': None}}

# %%
response = requests.post(assign_url,headers=headers_partner)

# %%
response.json()
# Out:
# {'message': 'Service already assigned'}

# %%
response = requests.post(fulfill_url,headers=headers_user)

# %%
response.json()
# Out:
# {'message': 'Service Successfully marked as Fulfilled.'}

# %%
response = requests.post(complete_url,headers=headers_partner)

# %%
response.json()
# Out:
# {'message': 'Service Successfully marked as Completed.'}

# %%
params = {
    "cancellationReason": "Not required anymore"
}

# %%
response = requests.get('https://f583-2405-201-d010-1007-35ef-fff6-c6c0-70b7.ngrok-free.app/api/services/myServices' ,headers=headers_user)

# %%
response.json()
# Out:
# [{'serviceId': 6,
#   'serviceRequestId': 'SA0620624175268399',
#   'servicer': {'id': None,
#    'username': None,
#    'email': 'testpartner@example.com',
#    'phoneNumber': '8080808080',
#    'password': None,
#    'firstName': 'John',
#    'lastName': None,
#    'address': None,
#    'city': None,
#    'state': None,
#    'country': None,
#    'role': None},
#   'servicee': {'id': None,
#    'username': None,
#    'email': 'testuser@example.com',
#    'phoneNumber': '1234567890',
#    'password': None,
#    'firstName': 'John',
#    'lastName': None,
#    'address': None,
#    'city': None,
#    'state': None,
#    'country': None,
#    'role': None},
#   'category': 'Tutor/ Teacher',
#   'description': 'teach AI to kids',
#   'address': '4th main mysore',
#   'price': 45500.0,
#   'scheduledDate': '2025-03-28',
#   'scheduledTime': '04:00:00',
#   'expectedCompletion': '2025-03-29T10:30:00',
#   'status': 'Cancelled',
#   'cancellationReason': None,
# ...
